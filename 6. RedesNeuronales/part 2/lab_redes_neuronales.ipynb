# %% [markdown]
# # Laboratorio Redes Neuronales
#
# ## Sergio Diaz
#
# ## 19 de Mayo del 2023

# %% [markdown]
# ## Desarrolle una Red Neuronal Artificial con Keras y Tensorflow para la compuerta XOR.
#
# Tenemos dos entradas binarias (1 ó 0) y la salida es 1 si una de las entradas es verdadera (1) y la otra falsa (0).
#
# Es decir que de cuatro combinaciones posibles, sólo dos tienen salida 1 y las otras dos serán 0, como vemos aquí:
#
# * XOR(0,0) = 0
# * XOR(0,1) = 1
# * XOR(1,0) = 1
# * XOR(1,1) = 0

# %% [markdown]
# ### Cargue de las librerías

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# %% [markdown]
# ### Se cargan las entradas

# %%
datos_entrenamiento = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], "float32")

datos_entrenamiento
# Out:
# array([[0., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.]], dtype=float32)

# %% [markdown]
# ### Se cargan las salidas

# %%
datos_salida = np.array([[0], [1], [1], [0]], "float32")

# %% [markdown]
# ### Se programa la red neuronal

# %%
# Crear el modelo de la red neuronal
model = Sequential()
model.add(Dense(4, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Entrenar el modelo
model.fit(datos_entrenamiento, datos_salida, epochs=350)
# Out:
# Epoch 1/350
# 1/1 [==============================] - 1s 881ms/step - loss: 0.7089 - accuracy: 0.5000
# Epoch 2/350
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7086 - accuracy: 0.2500
# Epoch 3/350
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7084 - accuracy: 0.2500
# Epoch 4/350
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7081 - accuracy: 0.2500
# Epoch 5/350
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7078 - accuracy: 0.2500
# Epoch 6/350
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7076 - accuracy: 0.2500
# Epoch 7/350
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7073 - accuracy: 0.2500
# Epoch 8/350
# 1/1 [==============================] - 0s 19ms/step - loss: 0.7071 - accuracy: 0.2500
# Epoch 9/350
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7068 - accuracy: 0.2500
# Epoch 10/350
# ...

# %%
scores = model.evaluate(datos_entrenamiento, datos_salida)

print(model.metrics_names[1], scores[1]*100)
print(model.predict(datos_entrenamiento).round())
# Out:
# 1/1 [==============================] - 0s 127ms/step - loss: 0.6389 - accuracy: 1.0000
# accuracy 100.0
# 1/1 [==============================] - 0s 80ms/step
# [[0.]
#  [1.]
#  [1.]
#  [0.]]

# %%
# Predecir las salidas para los datos de entrenamiento y comparar con las salidas reales
predictions = model.predict(datos_entrenamiento).round()
print('Predictions:')
for i in range(len(datos_entrenamiento)):
    print(datos_entrenamiento[i], '-> Valor Predecido:', predictions[i], 'Valor Salida:', datos_salida[i])
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Predictions:
# [0. 0.] -> Valor Predecido: [0.] Valor Salida: [0.]
# [0. 1.] -> Valor Predecido: [1.] Valor Salida: [1.]
# [1. 0.] -> Valor Predecido: [1.] Valor Salida: [1.]
# [1. 1.] -> Valor Predecido: [0.] Valor Salida: [0.]
